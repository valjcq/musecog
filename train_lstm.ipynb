# %% [markdown]
# # Import libraries

# %%
import os
import copy
from datetime import date, datetime

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

seed = 42
torch.manual_seed(seed)

from dataloader import PianoRollDataset
from models import LSTM
from utils.midi_processing import convert_midi_to_piano_roll
from utils.visuals import visualize_sequence, make_video
from utils.export import export_features
# Out:
# Using device: cuda

# %% [markdown]
# # Convert midi dataset to piano roll
#
# This cell converts midi files to piano rolls, to save computation time during training. Make sure to prepare ```train```, ```validation``` and ```test``` subsets before running this.
#
# The time sampling of the piano rolls must be specified when converting the files, but they can be downsampled when they are loaded later on. The ```dataset_fs``` value should be equal or superior to the desired time sampling (in Hz).
#
# Run this cell even if the data are already preprocessed, to define the ```path``` and  ```dataset_fs``` variables.

# %%
midi_path = './data/midi_dataset_example/'  # Path to the MIDI dataset, containing train, validation, and test subfolders
pr_path = './data/pr_dataset/'              # Path where the dataset will be stored with a piano roll format

dataset_fs = 30                             # Sampling frequency used to convert MIDI files to piano roll format. The piano rolls
                                            # can be automatically downsampled when they're preloaded before the training loop.

if not os.path.exists(pr_path):
    subsets = ['train/', 'validation/', 'test/']
    for subset in subsets:
        print(f'Converting MIDI files to piano roll format for the {subset} subset...')
        os.makedirs(pr_path + subset, exist_ok=True)
        convert_midi_to_piano_roll(data_path = midi_path + subset, out_dir = pr_path + subset, 
                                    fs = dataset_fs, pedal_threshold = 64)

# %% [markdown]
# # Load dataset
#
# To save some computation time when using large training datasets, it is recommanded to load the data in RAM with ```preload = True```. This may take several minutes.
#
#
# The ```model_fs``` defines the time sampling (in Hz) of the data that the model will receive as input, and thus determines the temporal resolution of the model itself. This value can be inferior or equal to ```dataset_fs```.
#
# The ```ons_value``` and ```sus_value``` define the numerical value that indicate the onset or the sustain of a note in the model's inputs. Changing these values should have little impact on the model's performance. An absence of note is always indicated as ```0```.
#
# The ```max_seq_length``` set the maximum length of the input of the model (in timesteps).

# %%
dataset_path = pr_path                  # Path to the dataset in piano roll format.
preload = True                          # If True, the entire dataset is loaded into memory. This will speed up the training process,
                                        # but takes some time at loading, and requires a large amount of RAM.

model_fs = 20                           # Sampling frequency of the model. This value can only be equal or lower 
                                        # than the sampling frequency of the dataset.
batch_size = 16                         # Number of sequences processed in parallel by the model during training.
ons_value = 1                           # Value indicating the onset of a note in the model's input.
sus_value = 0.5                         # Value indicating the sustain of a note in the model's input.
padding_value = -99                     # Value used to pad the input sequences to the same length.
max_seq_length = 60*model_fs            # Maximum length of the input sequence in timesteps.

train_dataset = PianoRollDataset(data_path = dataset_path + 'train/', 
               dataset_fs = dataset_fs, model_fs = model_fs, 
               ons_value = ons_value, sus_value = sus_value, 
               padding_value = padding_value,
               source_length = max_seq_length,
               use_transposition = True,
               preload = preload, device = device, dtype = torch.float32)

validation_dataset = PianoRollDataset(data_path = dataset_path + 'validation/', 
               dataset_fs = dataset_fs, model_fs = model_fs, 
               ons_value = ons_value, sus_value = sus_value, 
               padding_value = padding_value,
               source_length = max_seq_length,
               use_transposition = True,
               preload = preload, device = device, dtype = torch.float32)

train_loader = DataLoader(train_dataset, batch_size=batch_size, collate_fn = train_dataset.collate_batch,
                        shuffle=True, num_workers=0)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, collate_fn = validation_dataset.collate_batch,
                        shuffle=True, num_workers=0)

# %% [markdown]
# # Instanciate model
#
# All the usual LSTM and optimizer parameters are listed below (see pytorch documentation).
#
# If ```run_name = None```, a new folder will be created to store the checkpoints during training.
# To resume the training of a model, set ```run_name``` to the name of its folder.

# %%
run_name = None     #if None, create a new run folder (named with the current date and time) and start training from scratch
                    #else, set the name of the folder to resume training from (e.g. 'lstm_run_Oct20_20-32-25')

#model parameters
input_size = 88             #dimension of the input sequence. In this case, it is the number of piano keys
output_size = 88            #dimension of the output sequence

n_lstm_layers = 1           #number of LSTM layers
hidden_dim = 128            #dimension of the hidden state of the LSTM
trunc_tw = 5*model_fs       #truncated backpropagation through time (BPTT) length. This will affect the ability of the model to learn long-term dependencies.
                            #A large value will allow the model to learn dependencies over longer time scales, but the model may fail to learn anything.
                            #A small value will restrict the learning to short-term dependencies, but the model has a higher chance of learning effectively.
dropout = 0.1               #dropout rate

#model initialization
model = LSTM(input_size, n_lstm_layers, hidden_dim, output_size, 
                 dropout, padding_value, device)
model.to(device)

#optimizer
lr = 1e-4               #learning rate
betas = (0.9, 0.98)     #betas for the Adam optimizer
eps = 1e-9              #epsilon for the Adam optimizer
optimizer = optim.Adam(model.parameters(), lr=lr, betas=betas, eps=eps)

#load model and optimizer state from the last checkpoint or start from scratch
if run_name is None:
    i_batch = 0

    date_run = date.today().strftime('%b%d') + '_' + datetime.now().strftime('%H-%M-%S')
    run_path = './runs/lstm_run_' + date_run + '/'
    if os.path.exists(run_path) == False:
        os.makedirs(run_path, exist_ok=True)
    writer = SummaryWriter(log_dir = run_path)                # Create a tensorboard writer to store training/validation losses, 
                                                              # and plot dynamic graphs during training (see tensorboard's documentation).
    loss_history = {'train_loss': [], 'validation_loss': []}  # Custom history of losses. Tensorboard's writer is efficient, but can
                                                              # occasionally produce corrupted files. This custom history is a safety measure. 

else:
    run_path = './runs/' + run_name + '/'
    tmp = []
    for file in os.listdir(run_path):
        if 'model_' in file:
            i_batch = int(file.split('_')[1].split('.')[0])
            tmp.append(i_batch)
    i_batch = max(tmp)
    
    writer = SummaryWriter(run_path)
    loss_history = np.load(run_path + 'loss_history.npy', allow_pickle=True).item()

    model_path = run_path + 'model_' + str(i_batch) + '.pt'
    model.load_state_dict(torch.load(model_path))
    optimizer_path = run_path + 'optimizer_' + str(i_batch) + '.pt'
    optimizer.load_state_dict(torch.load(optimizer_path))

# %% [markdown]
# # Training
#
# When running the training loop, the training and validation losses will be stored with a TensordBoard writer, and can be visualized by lauching a TensorBoard session. Since TensorBoard can sometimes be unreliable, the loss values are also stored in the ```loss_history``` dictionnary.
#
# The model state will be automatically saved during training, from every 1K batches at the beginning to every 25K batches later on.
#
# The training loop can be manually stopped and resumed at any time. The next cell allows you to save the model manually.

# %%
n_batch = 1500000

# The training loop can be manually stopped and resumed. Use the next cell to manually save the model state.
while i_batch <= n_batch:
    for (src, tgt) in train_loader:
        model.train()

        t = 0
        loss_batch = []
        (h,c) = model.init_hidden(batch_size = src.shape[0])
        while t < src.shape[1]:
            optimizer.zero_grad()

            step = min(trunc_tw, src.shape[1] - t)
            src_trunc = src[:,t:t+step,:]
            tgt_trunc = tgt[:,t:t+step,:]

            output, (h,c) = model(src_trunc, (h,c))
            loss = model.criterion(output, tgt_trunc)
            loss.backward()
            optimizer.step()
            h,c = h.detach_(), c.detach_()

            loss_batch.append(loss.item())
            t += step

        #tensorboard
        training_loss = np.mean(loss_batch)
        if i_batch % 10 == 0:
            writer.add_scalar('Loss/train', training_loss, i_batch)
            loss_history['train_loss'].append((training_loss, i_batch))

        # print(f"Batch: {i_batch}, Loss: {np.round(loss.item(),4)}")

        #validation loop
        if i_batch % 100 == 0:
            model.eval()
            (h,c) = model.init_hidden(batch_size = src.shape[0])
            with torch.no_grad():
                src, tgt = next(iter(validation_loader))
                output, (h,c) = model(src, (h,c))
                loss = model.criterion(output, tgt)
                
            
            validation_loss = copy.copy(loss.item())
            writer.add_scalar('Loss/validation', validation_loss, i_batch)
            loss_history['validation_loss'].append((validation_loss, i_batch))
            print(f"Batch: {i_batch}")
            print(f" --- Training loss: {np.round(training_loss,4)}")
            print(f" --- Validation loss: {np.round(validation_loss,4)}")

            #visual representation of model output to tensorboard
            if i_batch % 1000 == 0:
                max_t = 25*model_fs
                fig = visualize_sequence(src[0,:max_t,:], tgt[0,:max_t,:], output[0,:max_t,:])
                writer.add_figure('Visual/Validation', fig, i_batch)
            
            model.train()

        #save model
        if (i_batch % 1000 == 0 and i_batch < 10000) or (i_batch % 5000 == 0 and i_batch < 100000) or (i_batch % 10000 == 0 and i_batch < 300000) or (i_batch % 25000 == 0 and i_batch > 300000):
            torch.save(model.state_dict(), run_path + f'/model_{i_batch}.pt')
            torch.save(optimizer.state_dict(), run_path + f'/optimizer_{i_batch}.pt')
            np.save(run_path + 'loss_history.npy', loss_history)

            print(f'Model saved at batch {i_batch}')

        i_batch += 1
# Out:
# Batch: 0
#  --- Training loss: 60.7829
#  --- Validation loss: 60.5586
# can't invoke "event" command: application has been destroyed
#     while executing
# "event generate $w <<ThemeChanged>>"
#     (procedure "ttk::ThemeChanged" line 6)
#     invoked from within
# "ttk::ThemeChanged"
# Model saved at batch 0
# Batch: 100
#  --- Training loss: 2.9671
#  --- Validation loss: 3.0431
# Batch: 200
#  --- Training loss: 3.1074
#  --- Validation loss: 2.5058
# Batch: 300
#  --- Training loss: 2.9364
#  --- Validation loss: 2.7211
# Batch: 400
#  --- Training loss: 3.0789
#  --- Validation loss: 2.8573
# Batch: 500
#  --- Training loss: 2.6056
#  --- Validation loss: 2.6105
# Batch: 600
#  --- Training loss: 2.9142
#  --- Validation loss: 2.8312
# Batch: 700
#  --- Training loss: 3.0666
#  --- Validation loss: 2.9923
# Batch: 800
#  --- Training loss: 3.3387
#  --- Validation loss: 2.9645
# Batch: 900
#  --- Training loss: 3.1429
#  --- Validation loss: 2.5849
# Batch: 1000
#  --- Training loss: 2.3964
#  --- Validation loss: 2.7029
# Model saved at batch 1000
# Batch: 1100
#  --- Training loss: 2.6683
#  --- Validation loss: 2.5813
# Batch: 1200
#  --- Training loss: 2.6501
#  --- Validation loss: 2.6848
# Batch: 1300
#  --- Training loss: 2.8809
#  --- Validation loss: 2.9873
# Batch: 1400
#  --- Training loss: 2.42
#  --- Validation loss: 3.0876
# Batch: 1500
#  --- Training loss: 2.8373
#  --- Validation loss: 2.4398
# Batch: 1600
#  --- Training loss: 2.3991
#  --- Validation loss: 2.27
# Batch: 1700
#  --- Training loss: 2.8182
#  --- Validation loss: 2.6959
# Batch: 1800
#  --- Training loss: 2.6553
#  --- Validation loss: 2.3761
# Batch: 1900
#  --- Training loss: 3.1107
#  --- Validation loss: 2.6721
# Batch: 2000
#  --- Training loss: 2.6279
#  --- Validation loss: 2.6756
# Model saved at batch 2000
# Batch: 2100
#  --- Training loss: 3.3492
#  --- Validation loss: 2.8235
# Batch: 2200
#  --- Training loss: 3.1109
#  --- Validation loss: 2.7734
# Batch: 2300
#  --- Training loss: 3.1629
#  --- Validation loss: 2.4826
# Batch: 2400
#  --- Training loss: 2.5816
#  --- Validation loss: 3.0608
# Batch: 2500
#  --- Training loss: 2.9923
#  --- Validation loss: 2.0072
# Batch: 2600
#  --- Training loss: 2.5032
#  --- Validation loss: 2.7302
# Batch: 2700
#  --- Training loss: 2.9859
#  --- Validation loss: 2.7151
# Batch: 2800
#  --- Training loss: 2.5076
#  --- Validation loss: 2.4356
# Batch: 2900
#  --- Training loss: 2.8657
#  --- Validation loss: 2.51
# Batch: 3000
#  --- Training loss: 3.0618
#  --- Validation loss: 2.6443
# Model saved at batch 3000
# Batch: 3100
#  --- Training loss: 2.243
#  --- Validation loss: 2.9134
# Batch: 3200
#  --- Training loss: 3.0969
#  --- Validation loss: 2.4857
# Batch: 3300
#  --- Training loss: 3.1316
#  --- Validation loss: 2.666
# Batch: 3400
#  --- Training loss: 2.8177
#  --- Validation loss: 2.5797
# Batch: 3500
#  --- Training loss: 2.9697
#  --- Validation loss: 2.2899
# Batch: 3600
#  --- Training loss: 2.751
#  --- Validation loss: 2.6454
# Batch: 3700
#  --- Training loss: 2.8087
#  --- Validation loss: 2.4696
# Batch: 3800
#  --- Training loss: 2.8288
#  --- Validation loss: 2.4342
# Batch: 3900
#  --- Training loss: 2.4305
#  --- Validation loss: 2.3581
# Batch: 4000
#  --- Training loss: 3.0797
#  --- Validation loss: 2.248
# Model saved at batch 4000
# Batch: 4100
#  --- Training loss: 2.6912
#  --- Validation loss: 2.8199
# Batch: 4200
#  --- Training loss: 2.7094
#  --- Validation loss: 3.0496
# Batch: 4300
#  --- Training loss: 3.125
#  --- Validation loss: 2.2139
# Batch: 4400
#  --- Training loss: 2.4745
#  --- Validation loss: 3.0995
# Batch: 4500
#  --- Training loss: 2.634
#  --- Validation loss: 2.2226
# Batch: 4600
#  --- Training loss: 2.9044
#  --- Validation loss: 2.507
# Batch: 4700
#  --- Training loss: 3.3354
#  --- Validation loss: 2.4461
# Batch: 4800
#  --- Training loss: 2.8469
#  --- Validation loss: 2.4513
# Batch: 4900
#  --- Training loss: 2.7974
#  --- Validation loss: 1.8803
# Batch: 5000
#  --- Training loss: 2.5383
#  --- Validation loss: 2.4193
# Model saved at batch 5000
# Batch: 5100
#  --- Training loss: 2.6533
#  --- Validation loss: 2.3081
# Batch: 5200
#  --- Training loss: 2.5641
#  --- Validation loss: 2.1771
# Batch: 5300
#  --- Training loss: 2.5068
#  --- Validation loss: 2.5198
# Batch: 5400
#  --- Training loss: 2.8069
#  --- Validation loss: 2.8245
# Batch: 5500
#  --- Training loss: 2.5598
#  --- Validation loss: 2.7778
# Batch: 5600
#  --- Training loss: 3.0014
#  --- Validation loss: 2.1205
# Batch: 5700
#  --- Training loss: 2.3076
#  --- Validation loss: 2.4671
# Batch: 5800
#  --- Training loss: 2.7949
#  --- Validation loss: 2.4027
# Batch: 5900
#  --- Training loss: 2.8932
#  --- Validation loss: 2.5531
# Batch: 6000
#  --- Training loss: 2.9651
#  --- Validation loss: 2.0593
# Model saved at batch 6000
# Batch: 6100
#  --- Training loss: 2.523
#  --- Validation loss: 2.5516
# Batch: 6200
#  --- Training loss: 2.9954
#  --- Validation loss: 2.402
# Batch: 6300
#  --- Training loss: 2.6039
#  --- Validation loss: 2.5431
# Batch: 6400
#  --- Training loss: 2.2733
#  --- Validation loss: 2.1065
# Batch: 6500
#  --- Training loss: 2.6083
#  --- Validation loss: 2.7709
# Batch: 6600
#  --- Training loss: 3.4464
#  --- Validation loss: 2.7002
# Batch: 6700
#  --- Training loss: 2.6656
#  --- Validation loss: 2.839
# Batch: 6800
#  --- Training loss: 2.6657
#  --- Validation loss: 2.3696
# Batch: 6900
#  --- Training loss: 2.8674
#  --- Validation loss: 2.3471
# Batch: 7000
#  --- Training loss: 2.8626
#  --- Validation loss: 2.0803
# Model saved at batch 7000
# Batch: 7100
#  --- Training loss: 3.0284
#  --- Validation loss: 2.1202
# Batch: 7200
#  --- Training loss: 2.7274
#  --- Validation loss: 2.487
# Batch: 7300
#  --- Training loss: 2.7521
#  --- Validation loss: 2.8661
# Batch: 7400
#  --- Training loss: 3.2246
#  --- Validation loss: 2.5528
# Batch: 7500
#  --- Training loss: 2.725
#  --- Validation loss: 2.8594
# Batch: 7600
#  --- Training loss: 3.2724
#  --- Validation loss: 2.3429
# Batch: 7700
#  --- Training loss: 2.6862
#  --- Validation loss: 2.7252
# Batch: 7800
#  --- Training loss: 2.7574
#  --- Validation loss: 2.4736
# Batch: 7900
#  --- Training loss: 2.5715
#  --- Validation loss: 2.6296
# Batch: 8000
#  --- Training loss: 2.482
#  --- Validation loss: 2.6025
# Model saved at batch 8000
# Batch: 8100
#  --- Training loss: 2.5195
#  --- Validation loss: 2.8328
# Batch: 8200
#  --- Training loss: 2.4418
#  --- Validation loss: 2.8939
# Batch: 8300
#  --- Training loss: 2.6482
#  --- Validation loss: 2.8386
# Batch: 8400
#  --- Training loss: 2.7019
#  --- Validation loss: 2.4764
# Batch: 8500
#  --- Training loss: 2.7214
#  --- Validation loss: 2.8882
# Batch: 8600
#  --- Training loss: 3.1209
#  --- Validation loss: 2.7614
# Batch: 8700
#  --- Training loss: 2.6327
#  --- Validation loss: 2.4192
# Batch: 8800
#  --- Training loss: 2.5074
#  --- Validation loss: 2.6405
# Batch: 8900
#  --- Training loss: 3.0039
#  --- Validation loss: 2.6654
# Batch: 9000
#  --- Training loss: 2.3552
#  --- Validation loss: 2.6231
# Model saved at batch 9000
# Batch: 9100
#  --- Training loss: 3.0962
#  --- Validation loss: 2.4859
# Batch: 9200
#  --- Training loss: 2.6549
#  --- Validation loss: 2.5137
# Batch: 9300
#  --- Training loss: 2.5725
#  --- Validation loss: 2.9216
# Batch: 9400
#  --- Training loss: 2.5556
#  --- Validation loss: 2.0324
# Batch: 9500
#  --- Training loss: 2.9272
#  --- Validation loss: 2.665
# Batch: 9600
#  --- Training loss: 2.7799
#  --- Validation loss: 2.3899
# Batch: 9700
#  --- Training loss: 2.8397
#  --- Validation loss: 2.254
# Batch: 9800
#  --- Training loss: 2.9187
#  --- Validation loss: 2.5552
# Batch: 9900
#  --- Training loss: 2.8209
#  --- Validation loss: 2.4815
# Batch: 10000
#  --- Training loss: 2.6749
#  --- Validation loss: 2.7446
# Model saved at batch 10000
# Batch: 10100
#  --- Training loss: 2.7644
#  --- Validation loss: 2.3079
# Batch: 10200
#  --- Training loss: 2.9324
#  --- Validation loss: 2.334
# Batch: 10300
#  --- Training loss: 3.057
#  --- Validation loss: 2.9537
# Batch: 10400
#  --- Training loss: 2.7661
#  --- Validation loss: 2.5904
# Batch: 10500
#  --- Training loss: 3.2726
#  --- Validation loss: 2.1709
# Batch: 10600
#  --- Training loss: 2.9937
#  --- Validation loss: 2.5996
# Batch: 10700
#  --- Training loss: 2.9133
#  --- Validation loss: 2.9748
# Batch: 10800
#  --- Training loss: 2.7195
#  --- Validation loss: 2.7332
# Batch: 10900
#  --- Training loss: 2.6349
#  --- Validation loss: 2.2937
# Batch: 11000
#  --- Training loss: 2.3891
#  --- Validation loss: 2.7891
# Batch: 11100
#  --- Training loss: 2.7521
#  --- Validation loss: 2.496
# Batch: 11200
#  --- Training loss: 2.5495
#  --- Validation loss: 2.3648
# Batch: 11300
#  --- Training loss: 2.5849
#  --- Validation loss: 2.6281
# Batch: 11400
#  --- Training loss: 2.7172
#  --- Validation loss: 3.2365
# Batch: 11500
#  --- Training loss: 2.6543
#  --- Validation loss: 2.8178
# Batch: 11600
#  --- Training loss: 2.5699
#  --- Validation loss: 2.4926
# Batch: 11700
#  --- Training loss: 2.9097
#  --- Validation loss: 2.4683
# Batch: 11800
#  --- Training loss: 2.9023
#  --- Validation loss: 2.1672
# Batch: 11900
#  --- Training loss: 2.7787
#  --- Validation loss: 2.4873
# Batch: 12000
#  --- Training loss: 2.8071
#  --- Validation loss: 2.4505
# Batch: 12100
#  --- Training loss: 2.8473
#  --- Validation loss: 2.5148
# Batch: 12200
#  --- Training loss: 2.8032
#  --- Validation loss: 2.1283
# Batch: 12300
#  --- Training loss: 2.8678
#  --- Validation loss: 2.7848
# Batch: 12400
#  --- Training loss: 3.1325
#  --- Validation loss: 2.3575
# Batch: 12500
#  --- Training loss: 2.6491
#  --- Validation loss: 2.615
# Batch: 12600
#  --- Training loss: 2.989
#  --- Validation loss: 2.3134
# Batch: 12700
#  --- Training loss: 2.7008
#  --- Validation loss: 2.3201
# Batch: 12800
#  --- Training loss: 2.8638
#  --- Validation loss: 2.4321
# Batch: 12900
#  --- Training loss: 3.0013
#  --- Validation loss: 2.3207
# Batch: 13000
#  --- Training loss: 2.4964
#  --- Validation loss: 2.3688
# Batch: 13100
#  --- Training loss: 2.4524
#  --- Validation loss: 3.1772
# Batch: 13200
#  --- Training loss: 2.9547
#  --- Validation loss: 2.4338
# Batch: 13300
#  --- Training loss: 2.6544
#  --- Validation loss: 2.3281
# Batch: 13400
#  --- Training loss: 2.5233
#  --- Validation loss: 2.663
# Batch: 13500
#  --- Training loss: 2.6936
#  --- Validation loss: 2.6317
# Batch: 13600
#  --- Training loss: 2.7202
#  --- Validation loss: 2.7563
# Batch: 13700
#  --- Training loss: 3.1405
#  --- Validation loss: 2.4255
# Batch: 13800
#  --- Training loss: 2.8938
#  --- Validation loss: 2.3303
# Batch: 13900
#  --- Training loss: 2.7651
#  --- Validation loss: 2.7374
# Batch: 14000
#  --- Training loss: 2.9283
#  --- Validation loss: 2.4371
# Batch: 14100
#  --- Training loss: 2.3708
#  --- Validation loss: 2.7338
# Batch: 14200
#  --- Training loss: 2.2841
#  --- Validation loss: 2.2531
# Batch: 14300
#  --- Training loss: 2.5795
#  --- Validation loss: 2.4794
# Batch: 14400
#  --- Training loss: 2.282
#  --- Validation loss: 3.116
# Batch: 14500
#  --- Training loss: 2.7396
#  --- Validation loss: 2.2547
# Batch: 14600
#  --- Training loss: 3.1933
#  --- Validation loss: 2.445
# Batch: 14700
#  --- Training loss: 2.8328
#  --- Validation loss: 2.6434
# Batch: 14800
#  --- Training loss: 2.9639
#  --- Validation loss: 2.3806
# Batch: 14900
#  --- Training loss: 2.6585
#  --- Validation loss: 2.5489
# Batch: 15000
#  --- Training loss: 2.6984
#  --- Validation loss: 2.653
# Model saved at batch 15000
# Batch: 15100
#  --- Training loss: 2.572
#  --- Validation loss: 2.3792
# Batch: 15200
#  --- Training loss: 3.124
#  --- Validation loss: 2.5065
# Batch: 15300
#  --- Training loss: 2.8073
#  --- Validation loss: 2.3273
# Batch: 15400
#  --- Training loss: 3.3931
#  --- Validation loss: 2.4339
# Batch: 15500
#  --- Training loss: 3.1434
#  --- Validation loss: 1.898
# Batch: 15600
#  --- Training loss: 2.4853
#  --- Validation loss: 2.5303
# Batch: 15700
#  --- Training loss: 2.8183
#  --- Validation loss: 2.8839
# Batch: 15800
#  --- Training loss: 2.7184
#  --- Validation loss: 2.3131
# Batch: 15900
#  --- Training loss: 3.0225
#  --- Validation loss: 2.6805
# Batch: 16000
#  --- Training loss: 2.891
#  --- Validation loss: 2.3554
# Batch: 16100
#  --- Training loss: 2.8179
#  --- Validation loss: 2.5194
# Batch: 16200
#  --- Training loss: 3.5123
#  --- Validation loss: 2.5256
# Batch: 16300
#  --- Training loss: 3.0878
#  --- Validation loss: 3.1537
# Batch: 16400
#  --- Training loss: 3.0911
#  --- Validation loss: 2.1897
# Batch: 16500
#  --- Training loss: 2.8311
#  --- Validation loss: 2.4809
# Batch: 16600
#  --- Training loss: 2.2733
#  --- Validation loss: 2.6529
# Batch: 16700
#  --- Training loss: 2.5692
#  --- Validation loss: 2.4625
# Batch: 16800
#  --- Training loss: 2.6347
#  --- Validation loss: 2.8924
# Batch: 16900
#  --- Training loss: 3.18
#  --- Validation loss: 2.6991
# Batch: 17000
#  --- Training loss: 2.9172
#  --- Validation loss: 2.7397
# Batch: 17100
#  --- Training loss: 2.5801
#  --- Validation loss: 2.5603
# Batch: 17200
#  --- Training loss: 2.7243
#  --- Validation loss: 2.7543
# Batch: 17300
#  --- Training loss: 3.0961
#  --- Validation loss: 2.0721
# Batch: 17400
#  --- Training loss: 2.3647
#  --- Validation loss: 2.4766
# Batch: 17500
#  --- Training loss: 2.4205
#  --- Validation loss: 3.0967
# Batch: 17600
#  --- Training loss: 2.5437
#  --- Validation loss: 2.9058
# Batch: 17700
#  --- Training loss: 2.8429
#  --- Validation loss: 2.3897
# Batch: 17800
#  --- Training loss: 2.7512
#  --- Validation loss: 2.8061
# Batch: 17900
#  --- Training loss: 2.3224
#  --- Validation loss: 2.385
# Batch: 18000
#  --- Training loss: 2.7139
#  --- Validation loss: 2.12
# Batch: 18100
#  --- Training loss: 2.5673
#  --- Validation loss: 2.2398
# Batch: 18200
#  --- Training loss: 2.567
#  --- Validation loss: 2.5126
# Batch: 18300
#  --- Training loss: 2.9969
#  --- Validation loss: 2.6398
# Batch: 18400
#  --- Training loss: 2.9719
#  --- Validation loss: 2.516
# Batch: 18500
#  --- Training loss: 2.719
#  --- Validation loss: 2.3806
# Batch: 18600
#  --- Training loss: 2.7973
#  --- Validation loss: 2.3932
# Batch: 18700
#  --- Training loss: 2.6734
#  --- Validation loss: 2.6558
# Batch: 18800
#  --- Training loss: 2.7166
#  --- Validation loss: 2.4042
# Batch: 18900
#  --- Training loss: 2.1614
#  --- Validation loss: 2.9163
# Batch: 19000
#  --- Training loss: 3.1109
#  --- Validation loss: 1.9594
# Batch: 19100
#  --- Training loss: 2.5631
#  --- Validation loss: 2.1658
# Batch: 19200
#  --- Training loss: 2.6031
#  --- Validation loss: 2.4431
# Batch: 19300
#  --- Training loss: 3.3629
#  --- Validation loss: 2.5548
# Batch: 19400
#  --- Training loss: 2.6869
#  --- Validation loss: 2.6194
# Batch: 19500
#  --- Training loss: 3.0273
#  --- Validation loss: 2.3328
# Batch: 19600
#  --- Training loss: 3.1921
#  --- Validation loss: 2.7889
# Batch: 19700
#  --- Training loss: 2.639
#  --- Validation loss: 2.7492
# Batch: 19800
#  --- Training loss: 2.7771
#  --- Validation loss: 2.3561
# Batch: 19900
#  --- Training loss: 2.8781
#  --- Validation loss: 2.261
# Batch: 20000
#  --- Training loss: 2.316
#  --- Validation loss: 2.4287
# Model saved at batch 20000
# Batch: 20100
#  --- Training loss: 2.366
#  --- Validation loss: 2.9024
# Batch: 20200
#  --- Training loss: 3.168
#  --- Validation loss: 2.6243
# Batch: 20300
#  --- Training loss: 2.7308
#  --- Validation loss: 2.4337
# Batch: 20400
#  --- Training loss: 3.0263
#  --- Validation loss: 2.57
# Batch: 20500
#  --- Training loss: 2.6323
#  --- Validation loss: 2.0722
# Batch: 20600
#  --- Training loss: 2.153
#  --- Validation loss: 2.7745
# Batch: 20700
#  --- Training loss: 2.4648
#  --- Validation loss: 2.4013
# Batch: 20800
#  --- Training loss: 2.9996
#  --- Validation loss: 3.0555
# Batch: 20900
#  --- Training loss: 2.5671
#  --- Validation loss: 2.1127
# Batch: 21000
#  --- Training loss: 2.5374
#  --- Validation loss: 2.8568
# Batch: 21100
#  --- Training loss: 2.6692
#  --- Validation loss: 2.8192
# Batch: 21200
#  --- Training loss: 2.508
#  --- Validation loss: 2.3635
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 20
#      18 output, (h,c) = model(src_trunc, (h,c))
#      19 loss = model.criterion(output, tgt_trunc)
# ---> 20 loss.backward()
#      21 optimizer.step()
#      22 h,c = h.detach_(), c.detach_()
#
# File ~/Depot_Github/musecog/.venv.musecog/lib/python3.10/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/Depot_Github/musecog/.venv.musecog/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Depot_Github/musecog/.venv.musecog/lib/python3.10/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
#to save manually, run this cell
torch.save(model.state_dict(), run_path + f'/model_{i_batch}.pt')
torch.save(optimizer.state_dict(), run_path + f'/optimizer_{i_batch}.pt')
np.save(run_path + 'loss_history.npy', loss_history)
print(f'Model saved at batch {i_batch}')
# Out:
# Model saved at batch 21294

# %% [markdown]
# # Select best model
#
# This cell computes the validation loss over the entire validation set for each checkpoint of the model, and selects the model state with the lowest validation loss.
#
# To evaluate the model on a subsets of the checkpoints only, set the ```versions_range``` to the desired i_batch range.
#
# To speed up the process, the validation set can be arbitrarely divided by ```n```.

# %%
versions_range = [0, n_batch]  #range of model versions to evaluate
n = 1 #divide by n the validation set to speed up the process

#retrieve model versions to evaluate
checkpoints = []
for file in os.listdir(run_path):
    if 'model_' in file:
        i_batch = int(file.split('_')[1].split('.')[0])
        if i_batch >= versions_range[0] and i_batch <= versions_range[1]:
            checkpoints.append(i_batch)
checkpoints = np.sort(checkpoints).tolist()
print(f"Evaluating checkpoints: {checkpoints}")

#compute loss on entire validation set for each model version (this can take some time)
val_loss = []
for checkpoint in checkpoints:
    tmp = []
    model_path = run_path + 'model_' + str(checkpoint) + '.pt'
    model.load_state_dict(torch.load(model_path))       #make sure that the model has been instanciated before running this
    model.eval()

    i = 0
    for (src, tgt) in validation_loader:
        if i % n == 0: 
            (h,c) = model.init_hidden(batch_size = src.shape[0])
            with torch.no_grad():
                output, (h,c) = model(src, (h,c))
                loss = model.criterion(output, tgt)
                tmp.append(loss.item())
        i += 1
    print(f"Batch: {checkpoint}, Validation loss: {np.mean(tmp)}")
    val_loss.append(np.mean(tmp))

#retrieve best model
print('---')
best_model_checkpoint = checkpoints[np.argmin(val_loss)]
best_train_loss = loss_history['train_loss'][np.argmin([np.abs(s - best_model_checkpoint) for s in [s for (_, s) in loss_history['train_loss']]])][0]
best_val_loss = val_loss[np.argmin(val_loss)]
print(f"Best model: model_{best_model_checkpoint}")
print(f"Training loss: {best_train_loss}")
print(f"Validation loss: {best_val_loss}")
# Out:
# Evaluating checkpoints: [0, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 15000, 20000, 21294]
# Batch: 0, Validation loss: 60.558430671691895
# Batch: 1000, Validation loss: 2.7149558067321777
# Batch: 2000, Validation loss: 2.6704617738723755
# Batch: 3000, Validation loss: 2.5686495900154114
# Batch: 4000, Validation loss: 2.606316387653351
# Batch: 5000, Validation loss: 2.5589640140533447
# Batch: 6000, Validation loss: 2.57675963640213
# Batch: 7000, Validation loss: 2.5579344630241394
# Batch: 8000, Validation loss: 2.5223793983459473
# Batch: 9000, Validation loss: 2.583184063434601
# Batch: 10000, Validation loss: 2.5853047370910645
# Batch: 15000, Validation loss: 2.5764122009277344
# Batch: 20000, Validation loss: 2.5197783708572388
# Batch: 21294, Validation loss: 2.5324882864952087
# ---
# Best model: model_20000
# Training loss: 2.3160370786984763
# Validation loss: 2.5197783708572388

# %% [markdown]
# # Save final version
#
# The final version of a model is saved in ```'./versions/model_name/```, in a ```model.pt``` file. It can be loaded in other scripts with ```torch.load()```.
#
# All the parameters to instanciate, evaluate or fine-tune the model are saved in ```info.pt```.

# %%
name = 'lstm_maestro_test2'
additional_info = ''' Examplar model, trained on a subset of the MAESTRO 3.0 dataset. '''

os.makedirs('./versions/' + name, exist_ok=True)

model_path = run_path + 'model_' + str(best_model_checkpoint) + '.pt'
model.load_state_dict(torch.load(model_path))
optimizer_path = run_path + 'optimizer_' + str(best_model_checkpoint) + '.pt'
optimizer.load_state_dict(torch.load(optimizer_path))

if os.path.exists('./versions/' + name + '/model.pt'):
    print('A model already exists at this location !')
else:
    torch.save(model, './versions/' + name + '/model.pt')
    torch.save({'model_type': 'lstm',
                'seed': seed,
                'i_batch': best_model_checkpoint,
                'fs': model_fs,
                'ons_value': ons_value,
                'sus_value': sus_value,
                'padding_value': padding_value,
                'batch_size': batch_size,
                'input_size' : input_size,
                'output_size': output_size,
                'hidden_dim': hidden_dim,
                'n_lstm_layers': n_lstm_layers,
                'trunc_tw': trunc_tw,
                'max_seq_length': max_seq_length,
                'dropout': dropout,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss_history': loss_history,
                'train_loss': best_train_loss,
                'val_loss': best_val_loss,
                'additional_info': additional_info,
                }, 
                './versions/' + name + '/info.pt')

# %% [markdown]
# # Visualize with video
#
# The ```make_video()``` function requires fluidsynth and ffmpeg to work. Links are available on https://github.com/pl-robert/musecog.
#
# The video will be saved in ./versions/model_name/video/

# %%
make_video(file_path = './data/midi_dataset_example/visualization/',
            file_name = 'bach_prelude_fugue_c#M_wtc1.mid', #test_samples.mid
            res = (1280,720), 
            graph = True,
            model_name = 'PolyRNN',
            ffmpeg_path = 'ffmpeg-7.1')
# Out:
# Using device: cuda
# Preprocessing midi file:  bach_prelude_fugue_c#M_wtc1.mid
# Preprocessing midi file:  test_samples.mid
# 0 / 3898
# 100 / 3898
# 200 / 3898
# 300 / 3898
# 400 / 3898
# 500 / 3898
# 600 / 3898
# 700 / 3898
# 800 / 3898
# 900 / 3898
# 1000 / 3898
# 1100 / 3898
# 1200 / 3898
# 1300 / 3898
# 1400 / 3898
# 1500 / 3898
# 1600 / 3898
# 1700 / 3898
# 1800 / 3898
# 1900 / 3898
# 2000 / 3898
# 2100 / 3898
# 2200 / 3898
# 2300 / 3898
# 2400 / 3898
# 2500 / 3898
# 2600 / 3898
# 2700 / 3898
# 2800 / 3898
# 2900 / 3898
# 3000 / 3898
# 3100 / 3898
# 3200 / 3898
# 3300 / 3898
# 3400 / 3898
# 3500 / 3898
# 3600 / 3898
# 3700 / 3898
# 3800 / 3898
# 3898 / 3898
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 make_video(file_path = './data/midi_dataset_example/visualization/',
#       2             file_name = 'bach_prelude_fugue_c#M_wtc1.mid', #test_samples.mid
#       3             res = (1280,720),
#       4             graph = True,
#       5             model_name = 'PolyRNN',
#       6             ffmpeg_path = 'ffmpeg-7.1')
#
# File ~/Depot_Github/musecog/utils/visuals.py:276, in make_video(file_path, file_name, res, graph, model_name, ffmpeg_path)
#     274 #generate audio
#     275 score = pretty_midi.PrettyMIDI(file_path+file_name)
# --> 276 wv = score.fluidsynth(fs=44100, sf2_path='./utils/GU_font.sf2')
#     277 y = np.int16(wv * 2 ** 15)
#     278 audio = pydub.AudioSegment(y.tobytes(),
#     279                             sample_width=2,
#     280                             frame_rate=44100,
#     281                             channels=1)
#
# File ~/Depot_Github/musecog/.venv.musecog/lib/python3.10/site-packages/pretty_midi/pretty_midi.py:974, in PrettyMIDI.fluidsynth(self, fs, sf2_path)
#     972     return np.array([])
#     973 # Get synthesized waveform for each instrument
# --> 974 waveforms = [i.fluidsynth(fs=fs,
#     975                           sf2_path=sf2_path) for i in self.instruments]
#     976 # Allocate output waveform, with #sample = max length of all waveforms
#     977 synthesized = np.zeros(np.max([w.shape[0] for w in waveforms]))
#
# File ~/Depot_Github/musecog/.venv.musecog/lib/python3.10/site-packages/pretty_midi/pretty_midi.py:974, in <listcomp>(.0)
#     972     return np.array([])
#     973 # Get synthesized waveform for each instrument
# --> 974 waveforms = [i.fluidsynth(fs=fs,
#     975                           sf2_path=sf2_path) for i in self.instruments]
#     976 # Allocate output waveform, with #sample = max length of all waveforms
#     977 synthesized = np.zeros(np.max([w.shape[0] for w in waveforms]))
#
# File ~/Depot_Github/musecog/.venv.musecog/lib/python3.10/site-packages/pretty_midi/instrument.py:456, in Instrument.fluidsynth(self, fs, sf2_path)
#     453     sf2_path = pkg_resources.resource_filename(__name__, DEFAULT_SF2)
#     455 if not _HAS_FLUIDSYNTH:
# --> 456     raise ImportError("fluidsynth() was called but pyfluidsynth "
#     457                       "is not installed.")
#     459 if not os.path.exists(sf2_path):
#     460     raise ValueError("No soundfont file found at the supplied path "
#     461                      "{}".format(sf2_path))
#
# ImportError: fluidsynth() was called but pyfluidsynth is not installed.

# %% [markdown]
# # Export features
#
# The ```export_features()``` function allows you to compute and save a series of features of interest from a given model and midi dataset.
#
# The ```out_fs``` parameter defines the time sampling of time-resolved features. Even if a model runs at 20Hz, the features can be upsampled to align with continuous neural or behavioral data of interest.
#
# If ```timing_correction = True```, the small temporal misalignements caused by a low ```model_fs``` are corrected to match the exact note onset timings (from the midi files), at the cost of minor distorsion in the features values (linear interpolation).
#
# The following features are computed at each timestep:
# - **surprise:** Binary Cross Entropy (BCE) between the model's predictions and the target values
# - **surprise_max:** maximum BCE across all simulatenous notes
# - **surprise_scaled:** BCE scaled by the number of simultaneous notes in the target
# - **surprise_positive:** positive part of the BCE
# - **surprise_positive_max:** maximum positive part of the BCE across all simulatenous notes
# - **surprise_positive_scaled:** positive part of the BCE scaled by the number of simultaneous notes in the target
# - **surprise_negative:** negative part of the BCE
# - **surprise_negative_max:** maximum negative part of the BCE across all absent notes
# - **surprise_negative_scaled:** negative part of the BCE scaled by the number of absent notes in the target
# - **uncertainty:** entropy of the model's predictions. The probabilities are normalized (sum = 1) before computing the entropy.
# - **predicted_density:** predicted note density (sum of probabilities)
#
# They are stored in the files:
# - **features.csv:** contains a summary of the features of all midi files in a single table. Each feature is summed over time, either across all timesteps ('continuous_xxx' features) or only at the timesteps with note onsets ('onsets_xxx' features). In addition, the table contains the number of notes, events (group of simulatenous notes) and the duration of each file.
# - **features_over_time:** folder containing the time-resolved features for each midi file. Each file contain all features, with the addition of a time axis and a binary mask for the note onsets.

# %%
export_features(data_path = './my_stimuli/midi/',
           output_path = './my_stimuli/',
           model_name = 'PolyRNN',
           out_fs = 100,
           timing_correction = False)
# Out:
# Using device: cuda
# Preprocessing midi file:  MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_03_WAV.midi
# Preprocessing midi file:  MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.midi
# Preprocessing midi file:  MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_02_Track02_wav.midi
# Computing predictions for sample  1 / 3 :  MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_02_Track02_wav.pt
# Computing predictions for sample  2 / 3 :  MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_03_WAV.pt
# Computing predictions for sample  3 / 3 :  MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1.pt
# Computing features for sample  1 / 3 :  MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_02_Track02_wav
# Computing features for sample  2 / 3 :  MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_03_WAV
# Computing features for sample  3 / 3 :  MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_01_R1_2014_wav--1
